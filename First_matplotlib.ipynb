# %% [markdown]
# <a href="https://colab.research.google.com/github/divya18696/Google_Colab/blob/main/First_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plp
import numpy as np

xplot = np.array ([1,4])
yplot =np.array ([0,80])

print(plp.plot(xplot,yplot))
# Out:
# [<matplotlib.lines.Line2D object at 0x7de13a3e7a60>]
